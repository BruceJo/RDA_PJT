# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import timeseries_dataset_from_array
from tensorflow import keras

# %%
LSTM_normal_model1 = keras.models.load_model('./LSTM_normal_model_epoch5k')
LSTM_shared_input_model1 = keras.models.load_model('./LSTM_shared_input_model_epoch5k')
LSTM_multiple_model1 = keras.models.load_model('./LSTM_multiple_model_epoch5k')
LSTM_shared_feature_model1 = keras.models.load_model('./LSTM_shared_feature_model_epoch5k')
GRU_normal_model1 = keras.models.load_model('./GRU_normal_model_epoch5k')
GRU_shared_input_model1 = keras.models.load_model('./GRU_shared_input_model_epoch5k')
GRU_multiple_model1 = keras.models.load_model('.GRU_multiple_model_epoch5k')
GRU_shared_feature_model1 = keras.models.load_model('./GRU_shared_feature_model_epoch5k')

# %%
keras.utils.plot_model(LSTM_normal_model1, show_layer_names=False)

# %%
keras.utils.plot_model(LSTM_shared_input_model1, show_layer_names=False)

# %%
keras.utils.plot_model(LSTM_multiple_model1, show_layer_names=False)

# %%
keras.utils.plot_model(LSTM_shared_feature_model1, show_layer_names=False)
